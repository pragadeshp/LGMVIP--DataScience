# %% [markdown]
# # BEGINNER LEVEL TASK
# # Task 2 - Stock Market Prediction and Forecasting using stacked LSTM
# ### Author: PRAGADESH P

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
data = pd.read_csv('https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv')
data.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2035 entries, 0 to 2034
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2035 non-null   object
#  1   Open                  2035 non-null   float64
#  2   High                  2035 non-null   float64
#  3   Low                   2035 non-null   float64
#  4   Last                  2035 non-null   float64
#  5   Close                 2035 non-null   float64
#  6   Total Trade Quantity  2035 non-null   int64
#  7   Turnover (Lacs)       2035 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 127.3+ KB

# %%
data.describe()
# Out:
#               Open         High          Low         Last       Close  \
# count  2035.000000  2035.000000  2035.000000  2035.000000  2035.00000
# mean    149.713735   151.992826   147.293931   149.474251   149.45027
# std      48.664509    49.413109    47.931958    48.732570    48.71204
# min      81.100000    82.800000    80.000000    81.000000    80.95000
# 25%     120.025000   122.100000   118.300000   120.075000   120.05000
# 50%     141.500000   143.400000   139.600000   141.100000   141.25000
# 75%     157.175000   159.400000   155.150000   156.925000   156.90000
# max     327.700000   328.750000   321.650000   325.950000   325.75000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          2.035000e+03      2035.000000
# mean           2.335681e+06      3899.980565
# std            2.091778e+06      4570.767877
# min            3.961000e+04        37.040000
# 25%            1.146444e+06      1427.460000
# 50%            1.783456e+06      2512.030000
# 75%            2.813594e+06      4539.015000
# max            2.919102e+07     55755.080000

# %%
data['Date'] = pd.to_datetime(data['Date'])
data.dtypes
# Out:
# Date                    datetime64[ns]
# Open                           float64
# High                           float64
# Low                            float64
# Last                           float64
# Close                          float64
# Total Trade Quantity             int64
# Turnover (Lacs)                float64
# dtype: object

# %%
data = data.sort_values('Date')
data.head()
# Out:
#            Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2034 2010-07-21  122.1  123.00  121.05  121.10  121.55                658666
# 2033 2010-07-22  120.3  122.00  120.25  120.75  120.90                293312
# 2032 2010-07-23  121.8  121.95  120.25  120.35  120.65                281312
# 2031 2010-07-26  120.1  121.00  117.10  117.10  117.60                658440
# 2030 2010-07-27  117.6  119.50  112.00  118.80  118.65                586100
#
#       Turnover (Lacs)
# 2034           803.56
# 2033           355.17
# 2032           340.31
# 2031           780.01
# 2030           694.98

# %%
plt.figure(figsize = (9,6))
plt.title('Tata Stocks Closing Price')
plt.plot(data['Close'],'r')
plt.xlabel('Date',fontsize=12)
plt.ylabel('Close',fontsize=12)
# Out:
# Text(0, 0.5, 'Close')

# %%
dcorr = data.corr()
top_corr_features = dcorr.index
plt.figure(figsize=(10,7))
#plot heatmap
sns.heatmap(data[top_corr_features].corr(), annot=True, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
data_close = data.reset_index()['Close']
data_close.head()
scaler = MinMaxScaler(feature_range = (0, 1))
data_close = scaler.fit_transform(np.array(data_close).reshape(-1, 1))

# %%
#### Splitting train, Test data

# %%
train_size = int(len(data_close)*0.70)
test_size = len(data_close) - train_size
train, test = data_close[0 : train_size, :], data_close[train_size : len(data_close), :1]

# %%
def create_matrix(ds, time_step=1):
    dataX, dataY = [], []
    for i in range(len(ds)-time_step-1):
        a = ds[i:(i+time_step),0]
        dataX.append(a)
        dataY.append(ds[i+time_step,0])
    return np.array(dataX), np.array(dataY)

# %%
step=100 # time step
X_train, y_train = create_matrix(train, step)
X_test, y_test = create_matrix(test, step)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1323, 100) (1323,)
# (510, 100) (510,)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# ### LSTM Model

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 100, 50)           10400
#
#  lstm_4 (LSTM)               (None, 100, 50)           20200
#
#  lstm_5 (LSTM)               (None, 50)                20200
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, validation_split=0.1, epochs=77, batch_size=64, verbose=1, shuffle=True).history
# Out:
# Epoch 1/77
# 19/19 [==============================] - 6s 163ms/step - loss: 0.0092 - val_loss: 0.0020
# Epoch 2/77
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 3/77
# 19/19 [==============================] - 2s 108ms/step - loss: 9.2169e-04 - val_loss: 0.0012
# Epoch 4/77
# 19/19 [==============================] - 2s 108ms/step - loss: 8.2582e-04 - val_loss: 0.0011
# Epoch 5/77
# 19/19 [==============================] - 2s 106ms/step - loss: 8.1474e-04 - val_loss: 0.0011
# Epoch 6/77
# 19/19 [==============================] - 2s 108ms/step - loss: 7.7653e-04 - val_loss: 0.0010
# Epoch 7/77
# 19/19 [==============================] - 2s 108ms/step - loss: 7.7130e-04 - val_loss: 9.7834e-04
# Epoch 8/77
# 19/19 [==============================] - 2s 108ms/step - loss: 7.2509e-04 - val_loss: 9.1029e-04
# Epoch 9/77
# 19/19 [==============================] - 2s 107ms/step - loss: 7.1088e-04 - val_loss: 8.4914e-04
# Epoch 10/77
# 19/19 [==============================] - 2s 109ms/step - loss: 6.8901e-04 - val_loss: 8.2510e-04
# Epoch 11/77
# 19/19 [==============================] - 2s 109ms/step - loss: 6.5705e-04 - val_loss: 7.7617e-04
# Epoch 12/77
# 19/19 [==============================] - 2s 108ms/step - loss: 6.3682e-04 - val_loss: 9.5024e-04
# Epoch 13/77
# 19/19 [==============================] - 2s 104ms/step - loss: 6.3715e-04 - val_loss: 8.7660e-04
# Epoch 14/77
# 19/19 [==============================] - 2s 107ms/step - loss: 6.2135e-04 - val_loss: 8.5086e-04
# Epoch 15/77
# 19/19 [==============================] - 2s 104ms/step - loss: 6.0422e-04 - val_loss: 6.9023e-04
# Epoch 16/77
# 19/19 [==============================] - 2s 103ms/step - loss: 6.0410e-04 - val_loss: 8.6387e-04
# Epoch 17/77
# 19/19 [==============================] - 2s 103ms/step - loss: 5.9534e-04 - val_loss: 6.3520e-04
# Epoch 18/77
# 19/19 [==============================] - 2s 100ms/step - loss: 5.9226e-04 - val_loss: 6.7990e-04
# Epoch 19/77
# 19/19 [==============================] - 2s 100ms/step - loss: 5.6343e-04 - val_loss: 6.3410e-04
# Epoch 20/77
# 19/19 [==============================] - 2s 105ms/step - loss: 5.4571e-04 - val_loss: 7.2117e-04
# Epoch 21/77
# 19/19 [==============================] - 2s 102ms/step - loss: 5.6893e-04 - val_loss: 5.6615e-04
# Epoch 22/77
# 19/19 [==============================] - 2s 101ms/step - loss: 5.2217e-04 - val_loss: 6.9100e-04
# Epoch 23/77
# 19/19 [==============================] - 2s 100ms/step - loss: 5.0700e-04 - val_loss: 6.2444e-04
# Epoch 24/77
# 19/19 [==============================] - 2s 102ms/step - loss: 4.8687e-04 - val_loss: 6.1476e-04
# Epoch 25/77
# 19/19 [==============================] - 2s 102ms/step - loss: 5.0160e-04 - val_loss: 5.2984e-04
# Epoch 26/77
# 19/19 [==============================] - 2s 118ms/step - loss: 4.7754e-04 - val_loss: 5.2486e-04
# Epoch 27/77
# 19/19 [==============================] - 2s 111ms/step - loss: 4.7087e-04 - val_loss: 4.8619e-04
# Epoch 28/77
# 19/19 [==============================] - 2s 100ms/step - loss: 5.6449e-04 - val_loss: 6.7117e-04
# Epoch 29/77
# 19/19 [==============================] - 2s 104ms/step - loss: 4.6848e-04 - val_loss: 5.3911e-04
# Epoch 30/77
# 19/19 [==============================] - 2s 114ms/step - loss: 4.4329e-04 - val_loss: 4.4776e-04
# Epoch 31/77
# 19/19 [==============================] - 2s 114ms/step - loss: 4.3820e-04 - val_loss: 4.4044e-04
# Epoch 32/77
# 19/19 [==============================] - 2s 110ms/step - loss: 4.4659e-04 - val_loss: 4.6918e-04
# Epoch 33/77
# 19/19 [==============================] - 2s 114ms/step - loss: 4.5940e-04 - val_loss: 4.4860e-04
# Epoch 34/77
# 19/19 [==============================] - 2s 114ms/step - loss: 4.2009e-04 - val_loss: 4.6485e-04
# Epoch 35/77
# 19/19 [==============================] - 2s 111ms/step - loss: 4.0106e-04 - val_loss: 4.5092e-04
# Epoch 36/77
# 19/19 [==============================] - 2s 103ms/step - loss: 3.9904e-04 - val_loss: 4.0602e-04
# Epoch 37/77
# 19/19 [==============================] - 2s 104ms/step - loss: 3.7296e-04 - val_loss: 3.6974e-04
# Epoch 38/77
# 19/19 [==============================] - 2s 104ms/step - loss: 3.7084e-04 - val_loss: 4.2549e-04
# Epoch 39/77
# 19/19 [==============================] - 2s 104ms/step - loss: 3.7240e-04 - val_loss: 3.9374e-04
# Epoch 40/77
# 19/19 [==============================] - 2s 103ms/step - loss: 3.6535e-04 - val_loss: 3.3500e-04
# Epoch 41/77
# 19/19 [==============================] - 2s 105ms/step - loss: 3.6752e-04 - val_loss: 3.3151e-04
# Epoch 42/77
# 19/19 [==============================] - 2s 108ms/step - loss: 3.4701e-04 - val_loss: 3.2719e-04
# Epoch 43/77
# 19/19 [==============================] - 2s 101ms/step - loss: 3.5027e-04 - val_loss: 3.7485e-04
# Epoch 44/77
# 19/19 [==============================] - 2s 115ms/step - loss: 3.3808e-04 - val_loss: 3.0048e-04
# Epoch 45/77
# 19/19 [==============================] - 2s 110ms/step - loss: 3.1876e-04 - val_loss: 2.9254e-04
# Epoch 46/77
# 19/19 [==============================] - 2s 108ms/step - loss: 3.1179e-04 - val_loss: 3.7474e-04
# Epoch 47/77
# 19/19 [==============================] - 2s 109ms/step - loss: 3.1394e-04 - val_loss: 2.7310e-04
# Epoch 48/77
# 19/19 [==============================] - 2s 107ms/step - loss: 2.9644e-04 - val_loss: 2.6549e-04
# Epoch 49/77
# 19/19 [==============================] - 2s 106ms/step - loss: 2.8819e-04 - val_loss: 2.6322e-04
# Epoch 50/77
# 19/19 [==============================] - 2s 117ms/step - loss: 3.0666e-04 - val_loss: 2.5940e-04
# Epoch 51/77
# 19/19 [==============================] - 2s 103ms/step - loss: 3.3193e-04 - val_loss: 3.8925e-04
# Epoch 52/77
# 19/19 [==============================] - 2s 101ms/step - loss: 2.8844e-04 - val_loss: 2.5397e-04
# Epoch 53/77
# 19/19 [==============================] - 2s 104ms/step - loss: 2.7294e-04 - val_loss: 2.4244e-04
# Epoch 54/77
# 19/19 [==============================] - 2s 101ms/step - loss: 2.7609e-04 - val_loss: 2.8120e-04
# Epoch 55/77
# 19/19 [==============================] - 2s 101ms/step - loss: 2.6144e-04 - val_loss: 2.2421e-04
# Epoch 56/77
# 19/19 [==============================] - 2s 102ms/step - loss: 2.5330e-04 - val_loss: 2.3704e-04
# Epoch 57/77
# 19/19 [==============================] - 2s 119ms/step - loss: 2.4605e-04 - val_loss: 2.1668e-04
# Epoch 58/77
# 19/19 [==============================] - 2s 109ms/step - loss: 2.5843e-04 - val_loss: 2.2029e-04
# Epoch 59/77
# 19/19 [==============================] - 2s 112ms/step - loss: 2.5663e-04 - val_loss: 2.2674e-04
# Epoch 60/77
# 19/19 [==============================] - 2s 111ms/step - loss: 2.4200e-04 - val_loss: 2.1029e-04
# Epoch 61/77
# 19/19 [==============================] - 2s 115ms/step - loss: 2.7969e-04 - val_loss: 2.1807e-04
# Epoch 62/77
# 19/19 [==============================] - 2s 106ms/step - loss: 2.8028e-04 - val_loss: 2.0343e-04
# Epoch 63/77
# 19/19 [==============================] - 2s 107ms/step - loss: 2.3556e-04 - val_loss: 2.0960e-04
# Epoch 64/77
# 19/19 [==============================] - 2s 106ms/step - loss: 2.2148e-04 - val_loss: 1.9353e-04
# Epoch 65/77
# 19/19 [==============================] - 2s 109ms/step - loss: 2.3270e-04 - val_loss: 1.8871e-04
# Epoch 66/77
# 19/19 [==============================] - 2s 107ms/step - loss: 2.1156e-04 - val_loss: 1.8979e-04
# Epoch 67/77
# 19/19 [==============================] - 2s 107ms/step - loss: 2.0666e-04 - val_loss: 1.8203e-04
# Epoch 68/77
# 19/19 [==============================] - 2s 108ms/step - loss: 2.1341e-04 - val_loss: 2.2901e-04
# Epoch 69/77
# 19/19 [==============================] - 2s 107ms/step - loss: 2.0576e-04 - val_loss: 1.8038e-04
# Epoch 70/77
# 19/19 [==============================] - 2s 105ms/step - loss: 2.0298e-04 - val_loss: 1.8655e-04
# Epoch 71/77
# 19/19 [==============================] - 2s 104ms/step - loss: 1.9336e-04 - val_loss: 1.9179e-04
# Epoch 72/77
# 19/19 [==============================] - 2s 102ms/step - loss: 1.9030e-04 - val_loss: 1.9672e-04
# Epoch 73/77
# 19/19 [==============================] - 2s 106ms/step - loss: 2.0742e-04 - val_loss: 1.6970e-04
# Epoch 74/77
# 19/19 [==============================] - 2s 101ms/step - loss: 2.3009e-04 - val_loss: 1.6359e-04
# Epoch 75/77
# 19/19 [==============================] - 2s 98ms/step - loss: 1.8421e-04 - val_loss: 2.1000e-04
# Epoch 76/77
# 19/19 [==============================] - 2s 98ms/step - loss: 2.0974e-04 - val_loss: 1.5414e-04
# Epoch 77/77
# 19/19 [==============================] - 2s 98ms/step - loss: 1.8020e-04 - val_loss: 1.5234e-04

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# %%
# Reversing the MinMax Scaler
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

# %%
import math
from sklearn.metrics import mean_squared_error

# %%
math.sqrt(mean_squared_error(y_train,train_predict))
math.sqrt(mean_squared_error(y_test,test_predict))
# Out:
# 209.57742194389243

# %%
### Visualise the Predictions
look_back = 100
train_num_pyredict_plot = np.empty_like(data_close)
train_num_pyredict_plot[:, :] = np.nan
train_num_pyredict_plot[look_back : len(train_predict) + look_back, :] = train_predict
test_predict_plot = np.empty_like(data_close)
test_predict_plot[:, :] = np.nan
test_predict_plot[len(train_predict) + (look_back * 2) + 1 : len(data_close) - 1, :] = test_predict
plt.plot(scaler.inverse_transform(data_close))
plt.plot(train_num_pyredict_plot)
plt.plot(test_predict_plot)
plt.show()

# %%
### Future Prediction Model
x_inum_pyut=test[307:].reshape(1, -1)
x_inum_pyut.shape
temp_inum_pyut = list(x_inum_pyut)
temp_inum_pyut = temp_inum_pyut[0].tolist()
temp_inum_pyut = list(x_inum_pyut)
temp_inum_pyut = temp_inum_pyut[0].tolist()

# %%
day_new = np.arange(1, 101)
day_pred = np.arange(101, 131)
plt.plot(day_new, scaler.inverse_transform(data_close[1935 : ]))

# %%
 Thank You
